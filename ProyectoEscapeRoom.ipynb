# %%
from funciones import *

juego()
# Out:
# Te despiertas en una habitación extraña.
# Estás en la Game room
# Moviendose...
# Lista de habitaciones:
# - Game room
# - Bedroom 1
# - Bedroom 2
# - Living room
# - Outside
# Estás en la Game room
# Acción no válida. Intenta nuevamente.
# Estás en la Game room
# Al examinar encuentras:
# ['Sofa', 'Piano']
# Tras examinar el piano encuentras una tecla que destaca sobre las demás
# Tras levantar la tecla no encuentras nada debajo, como es lógico, pero al mirar de frente ves una llave. *Llave A obtenida*
# Estás en la Game room
# Moviendose...
# Lista de habitaciones:
# - Game room
# - Bedroom 1
# - Bedroom 2
# - Living room
# - Outside
# Estás en la Bedroom 1
# Al examinar encuentras:
# ['Queen bed', 'Bedside table']
# Has encontrado otra llave. *Llave B obtenida*
# Estás en la Bedroom 1
# Moviendose...
# Lista de habitaciones:
# - Game room
# - Bedroom 1
# - Bedroom 2
# - Living room
# - Outside
# Estás en la Bedroom 2
# Al examinar encuentras:
# ['Double bed', 'Mirror']
# ...
